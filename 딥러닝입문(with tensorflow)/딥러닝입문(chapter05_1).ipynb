# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\dev\python312\lib\site-packages (2.17.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\dev\python312\lib\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\human\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\human\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.66.2)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\dev\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\dev\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\dev\python312\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.9.2)
# Requirement already satisfied: namex in c:\dev\python312\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\dev\python312\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\dev\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\dev\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\dev\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\dev\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\dev\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\dev\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\dev\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\dev\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\dev\python312\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\human\appdata\roaming\python\python312\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\dev\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install setuptools
# Out:
# Requirement already satisfied: setuptools in c:\dev\python312\lib\site-packages (75.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.datasets import fashion_mnist

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\dev\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dev\python312\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\dev\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dev\python312\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\dev\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\dev\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\human\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\dev\python312\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dev\python312\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\human\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\human\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
np.random.seed(777)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
sample_size = 9

# %%
random_idx = np.random.randint(60000, size = sample_size)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
x_train = np.reshape(x_train / 255, (-1, 28, 28, 1))
x_test = np.reshape(x_test / 255, (-1, 28, 28, 1))

# %%
from tensorflow.keras.utils import to_categorical

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\dev\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\dev\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\dev\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\dev\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\dev\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.3, random_state = 777)
print('Fashion-MNIST ready~')
# Out:
# Fashion-MNIST ready~

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
model = Sequential([
    Conv2D(filters = 16, kernel_size = 3, padding = 'same', activation = 'relu', input_shape = (28, 28, 1)),
    MaxPooling2D(pool_size = (2, 2), strides = 2, padding = 'same'),
    Conv2D(filters = 32, kernel_size = 3, padding = 'same', activation = 'relu'),
    MaxPooling2D(pool_size = (2, 2), strides = 2, padding = 'same'),
    Conv2D(filters = 64, kernel_size = 3, padding = 'same', activation = 'relu'),
    MaxPooling2D(pool_size = (2, 2), strides = 2, padding = 'same'),
    Flatten(),
    Dense(64, activation = 'relu'),
    Dense(10, activation = 'softmax')
])
# Out:
# c:\Dev\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics = ['acc'])
model.fit(x_train, y_train,
          epochs = 30,
          batch_size = 128,
          validation_data = (x_val, y_val))
# Out:
# Epoch 1/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - acc: 0.6455 - loss: 0.9765 - val_acc: 0.8323 - val_loss: 0.4683
# Epoch 2/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - acc: 0.8496 - loss: 0.4202 - val_acc: 0.8459 - val_loss: 0.4218
# Epoch 3/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - acc: 0.8672 - loss: 0.3650 - val_acc: 0.8803 - val_loss: 0.3388
# Epoch 4/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - acc: 0.8846 - loss: 0.3173 - val_acc: 0.8889 - val_loss: 0.3072
# Epoch 5/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.8925 - loss: 0.2895 - val_acc: 0.8869 - val_loss: 0.3115
# Epoch 6/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9012 - loss: 0.2667 - val_acc: 0.8978 - val_loss: 0.2846
# Epoch 7/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9106 - loss: 0.2495 - val_acc: 0.9024 - val_loss: 0.2740
# Epoch 8/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - acc: 0.9111 - loss: 0.2414 - val_acc: 0.9049 - val_loss: 0.2657
# Epoch 9/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - acc: 0.9196 - loss: 0.2217 - val_acc: 0.8980 - val_loss: 0.2956
# Epoch 10/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - acc: 0.9219 - loss: 0.2110 - val_acc: 0.9043 - val_loss: 0.2756
# Epoch 11/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - acc: 0.9261 - loss: 0.2006 - val_acc: 0.9102 - val_loss: 0.2584
# Epoch 12/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9306 - loss: 0.1875 - val_acc: 0.9053 - val_loss: 0.2653
# Epoch 13/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9322 - loss: 0.1835 - val_acc: 0.9040 - val_loss: 0.2745
# Epoch 14/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9400 - loss: 0.1672 - val_acc: 0.9126 - val_loss: 0.2472
# Epoch 15/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9379 - loss: 0.1655 - val_acc: 0.9147 - val_loss: 0.2529
# Epoch 16/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - acc: 0.9444 - loss: 0.1506 - val_acc: 0.9112 - val_loss: 0.2575
# Epoch 17/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9489 - loss: 0.1394 - val_acc: 0.9086 - val_loss: 0.2677
# Epoch 18/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9508 - loss: 0.1316 - val_acc: 0.9116 - val_loss: 0.2649
# Epoch 19/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9571 - loss: 0.1197 - val_acc: 0.9022 - val_loss: 0.2961
# Epoch 20/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9563 - loss: 0.1198 - val_acc: 0.9113 - val_loss: 0.2751
# Epoch 21/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9596 - loss: 0.1079 - val_acc: 0.9126 - val_loss: 0.2834
# Epoch 22/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - acc: 0.9628 - loss: 0.1004 - val_acc: 0.9142 - val_loss: 0.2759
# Epoch 23/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - acc: 0.9644 - loss: 0.0963 - val_acc: 0.9158 - val_loss: 0.2762
# Epoch 24/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9683 - loss: 0.0895 - val_acc: 0.9081 - val_loss: 0.3166
# Epoch 25/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9676 - loss: 0.0919 - val_acc: 0.9083 - val_loss: 0.3171
# Epoch 26/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - acc: 0.9707 - loss: 0.0791 - val_acc: 0.9142 - val_loss: 0.3120
# Epoch 27/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9749 - loss: 0.0674 - val_acc: 0.9145 - val_loss: 0.3321
# Epoch 28/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - acc: 0.9749 - loss: 0.0677 - val_acc: 0.9119 - val_loss: 0.3361
# Epoch 29/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - acc: 0.9719 - loss: 0.0778 - val_acc: 0.9127 - val_loss: 0.3459
# Epoch 30/30
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9819 - loss: 0.0507 - val_acc: 0.9154 - val_loss: 0.3435

# %%
from tensorflow.keras.datasets import fashion_mnist

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(x_train[0])

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\dev\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\dev\python312\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

import cv2

# %%
horizontal_filter = np.array([[1., 2., 1.],
                              [0., 0., 0.],
                              [-1., -2., -1.]])

# %%
vertical_filter = np.array([[1., 0., -1.],
                           [2., 0., -2.],
                           [1., 0., -1.]])

# %%
test_image = cv2.resize(x_train[0], (27, 27))
image_size = test_image.shape[0]
output_size = int((image_size - 3)/1 + 1)
print('output의크기 : %d' % output_size)
# Out:
# output의크기 : 25

# %%
filter_size = 3

# %%
filter_size = 3

def get_filtered_image(filter):
    filtered_image = np.zeros((output_size, output_size))
    
    for i in range(output_size):
        for j in range(output_size):
            # 합성곱 연산
            indice_image = test_image[i:(i + filter_size), j:(j + filter_size)] * filter
            indice_sum = np.sum(indice_image)

            if(indice_sum > 255):
                indice_sum = 255
            filtered_image[i, j] = indice_sum

    return filtered_image

vertical_filtered_image = get_filtered_image(vertical_filter)
horizontal_filtered_image = get_filtered_image(horizontal_filter)

plt.subplot(1, 2, 1)
plt.title('vertical')
plt.imshow(vertical_filtered_image)

plt.subplot(1, 2, 2)
plt.title('horizontal')
plt.imshow(horizontal_filtered_image)
plt.show()

# %%
sobel_image = np.sqrt(np.square(horizontal_filtered_image) + 
                      np.square(vertical_filtered_image))

plt.imshow(sobel_image)

# %%
import numpy as np


image = x_train[0]
image_x = image.shape[0]
image_y = image.shape[1]
new_image_x = int(image_x / 2)
new_image_y = int(image_y / 2)

pooled_image = np.zeros((new_image_x, new_image_y))

print(f'original image shape: ({image_x}, {image_y})')
print(f'pooled image shape: ({new_image_x}, {new_image_y})')

for x in range(0, image_x, 2):
    for y in range(0, image_y, 2):
        pooled_image[int(x/2), int(y/2)] = np.max(image[x:x + 2, y:y + 2])

plt.imshow(pooled_image)
# Out:
# original image shape: (28, 28)
# pooled image shape: (14, 14)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 7, 7, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 268,640 (1.02 MB)
#  Trainable params: 89,546 (349.79 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 179,094 (699.59 KB)

# %%
pip install pydot
# Out:
# Requirement already satisfied: pydot in c:\dev\python312\lib\site-packages (3.0.2)
# Requirement already satisfied: pyparsing>=3.0.9 in c:\dev\python312\lib\site-packages (from pydot) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\dev\python312\lib\site-packages (0.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.utils import plot_model

# %%
import os
os.environ["PATH"] += os.pathsep +'C:Program Files (x86)/Graphviz2.38/bin'

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, './model.png', show_shapes = True)
