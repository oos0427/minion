# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
Normal_key = "G0i7CupCMN2aQuW9UqapI6dkbgBPxmbwOY6LdFHjp3uuXRYzObOVsmBuaQUDjbxw8pOFFgYFXySOoacRP8NCjQ=="
url = "http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?dateType={0}&startDt={1}&serviceKey={2}&endDt={3}&stnIds={4}".format('XML', '20100101', Normal_key, '20100201', '108')
params ={'serviceKey' : Normal_key , 'pageNo' : '1', 'numOfRows' : '40', 'dataType' : 'XML', 'dataCd' : 'ASOS', 'dateCd' : 'DAY', 'startDt' : '20100101', 'endDt' : '20100201', 'stnIds' : '108' }

request = urllib.request.Request(url)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response><header><resultCode>11</resultCode><resultMsg>NO_MANDATORY_REQUEST_PARAMETERS_ERROR</resultMsg></header></response>

# %%
import requests
Normal_key = "G0i7CupCMN2aQuW9UqapI6dkbgBPxmbwOY6LdFHjp3uuXRYzObOVsmBuaQUDjbxw8pOFFgYFXySOoacRP8NCjQ=="


url = 'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList'
params ={'serviceKey' : Normal_key, 'pageNo' : '1', 'numOfRows' : '40', 'dataType' : 'JSON', 'dataCd' : 'ASOS', 'dateCd' : 'DAY', 'startDt' : '20240801', 'endDt' : '20240901', 'stnIds' : '108' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"stnId":"108","stnNm":"\xec\x84\x9c\xec\x9a\xb8","tm":"2024-08-01","avgTa":"29.9","minTa":"27.3","minTaHrmt":"0442","maxTa":"33.2","maxTaHrmt":"1520","mi10MaxRn":"0.3","mi10MaxRnHrmt":"405","hr1MaxRn":"0.3","hr1MaxRnHrmt":"320","sumRnDur":"1.42","sumRn":"0.3","maxInsWs":"7.1","maxInsWsWd":"180","maxInsWsHrmt":"1534","maxWs":"3.9","maxWsWd":"180","maxWsHrmt":"0733","avgWs":"2.6","hr24SumRws":"2268","maxWd":"200","avgTd":"25.0","minRhm":"64","minRhmHrmt":"1507","avgRhm":"75.5","avgPv":"31.6","avgPa":"994.5","maxPs":"1005.9","maxPsHrmt":"0108","minPs":"1002.0","minPsHrmt":"1615","avgPs":"1004.0","ssDur":"14.1","sumSsHr":"3.6","hr1MaxIcsrHrmt":"1400","hr1MaxIcsr":"2.17","sumGsr":"14.95","ddMefs":"","ddMefsHrmt":"","ddMes":"","ddMesHrmt":"","sumDpthFhsc":"","avgTca":"6.8","avgLmac":"6.8","avgTs":"30.6","minTg":"25.8","avgCm5Te":"29.0","avgCm10Te":"29.1","avgCm20Te":"28.3","
# ...

# %%
print(response.content)
print(type(response.content))
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"stnId":"108","stnNm":"\xec\x84\x9c\xec\x9a\xb8","tm":"2024-08-01","avgTa":"29.9","minTa":"27.3","minTaHrmt":"0442","maxTa":"33.2","maxTaHrmt":"1520","mi10MaxRn":"0.3","mi10MaxRnHrmt":"405","hr1MaxRn":"0.3","hr1MaxRnHrmt":"320","sumRnDur":"1.42","sumRn":"0.3","maxInsWs":"7.1","maxInsWsWd":"180","maxInsWsHrmt":"1534","maxWs":"3.9","maxWsWd":"180","maxWsHrmt":"0733","avgWs":"2.6","hr24SumRws":"2268","maxWd":"200","avgTd":"25.0","minRhm":"64","minRhmHrmt":"1507","avgRhm":"75.5","avgPv":"31.6","avgPa":"994.5","maxPs":"1005.9","maxPsHrmt":"0108","minPs":"1002.0","minPsHrmt":"1615","avgPs":"1004.0","ssDur":"14.1","sumSsHr":"3.6","hr1MaxIcsrHrmt":"1400","hr1MaxIcsr":"2.17","sumGsr":"14.95","ddMefs":"","ddMefsHrmt":"","ddMes":"","ddMesHrmt":"","sumDpthFhsc":"","avgTca":"6.8","avgLmac":"6.8","avgTs":"30.6","minTg":"25.8","avgCm5Te":"29.0","avgCm10Te":"29.1","avgCm20Te":"28.3","
# ...

# %%
text_response = response.content.decode('utf-8')

# %%
print(text_response)
print(type(text_response))
# Out:
# {"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"stnId":"108","stnNm":"서울","tm":"2024-08-01","avgTa":"29.9","minTa":"27.3","minTaHrmt":"0442","maxTa":"33.2","maxTaHrmt":"1520","mi10MaxRn":"0.3","mi10MaxRnHrmt":"405","hr1MaxRn":"0.3","hr1MaxRnHrmt":"320","sumRnDur":"1.42","sumRn":"0.3","maxInsWs":"7.1","maxInsWsWd":"180","maxInsWsHrmt":"1534","maxWs":"3.9","maxWsWd":"180","maxWsHrmt":"0733","avgWs":"2.6","hr24SumRws":"2268","maxWd":"200","avgTd":"25.0","minRhm":"64","minRhmHrmt":"1507","avgRhm":"75.5","avgPv":"31.6","avgPa":"994.5","maxPs":"1005.9","maxPsHrmt":"0108","minPs":"1002.0","minPsHrmt":"1615","avgPs":"1004.0","ssDur":"14.1","sumSsHr":"3.6","hr1MaxIcsrHrmt":"1400","hr1MaxIcsr":"2.17","sumGsr":"14.95","ddMefs":"","ddMefsHrmt":"","ddMes":"","ddMesHrmt":"","sumDpthFhsc":"","avgTca":"6.8","avgLmac":"6.8","avgTs":"30.6","minTg":"25.8","avgCm5Te":"29.0","avgCm10Te":"29.1","avgCm20Te":"28.3","avgCm30Te":"28.0","avgM0
# ...

# %%
import json

dict_response = json.loads(text_response)

# %%
dict_response
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'},
#   'body': {'dataType': 'JSON',
#    'items': {'item': [{'stnId': '108',
#       'stnNm': '서울',
#       'tm': '2024-08-01',
#       'avgTa': '29.9',
#       'minTa': '27.3',
#       'minTaHrmt': '0442',
#       'maxTa': '33.2',
#       'maxTaHrmt': '1520',
#       'mi10MaxRn': '0.3',
#       'mi10MaxRnHrmt': '405',
#       'hr1MaxRn': '0.3',
#       'hr1MaxRnHrmt': '320',
#       'sumRnDur': '1.42',
#       'sumRn': '0.3',
#       'maxInsWs': '7.1',
#       'maxInsWsWd': '180',
#       'maxInsWsHrmt': '1534',
#       'maxWs': '3.9',
#       'maxWsWd': '180',
#       'maxWsHrmt': '0733',
#       'avgWs': '2.6',
#       'hr24SumRws': '2268',
#       'maxWd': '200',
#       'avgTd': '25.0',
#       'minRhm': '64',
#       'minRhmHrmt': '1507',
#       'avgRhm': '75.5',
#       'avgPv': '31.6',
#       'avgPa': '994.5',
#       'maxPs': '1005.9',
#       'maxPsHrmt': '0108',
#       'minPs': '1002.0',
# ...

# %%
#print(dict_response.keys())
#print(dict_response['response'].keys())
#print(dict_response['response']['body'].keys())
#print(dict_response['response']['body']['items'].keys())
print(dict_response['response']['body']['items']['item'])
# Out:
# dict_keys(['item'])
# ...

# %%
import pandas as pd

df_documents = pd.DataFrame(dict_response['response']['body']['items']['item'])
df_documents.head()
# Out:
#   stnId stnNm          tm avgTa minTa minTaHrmt maxTa maxTaHrmt mi10MaxRn  \
# 0   108    서울  2024-08-01  29.9  27.3      0442  33.2      1520       0.3
# 1   108    서울  2024-08-02  29.6  28.2      0549  32.5      1608
# 2   108    서울  2024-08-03  30.2  27.2      0425  34.2      1528
# 3   108    서울  2024-08-04  31.8  27.3      0542  36.2      1448
# 4   108    서울  2024-08-05  30.0  26.9      2358  33.7      1522       0.5
#
#   mi10MaxRnHrmt  ... avgM05Te avgM10Te avgM15Te avgM30Te avgM50Te sumLrgEv  \
# 0           405  ...     28.2     26.0     25.2     20.4     17.4      3.4
# 1                ...     28.3     26.1     25.2     20.3     17.4      2.5
# 2                ...     28.3     26.1     25.2     20.3     17.4      4.7
# 3                ...     28.6     26.2     25.2     20.2     17.4      5.1
# 4           350  ...     29.0     26.3     25.3     20.2     17.4      2.8
#
#   sumSmlEv n99Rn                                               iscs sumFogDur
# ...

# %%
df_documents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 62 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   stnId           32 non-null     object
#  1   stnNm           32 non-null     object
#  2   tm              32 non-null     object
#  3   avgTa           32 non-null     object
#  4   minTa           32 non-null     object
#  5   minTaHrmt       32 non-null     object
#  6   maxTa           32 non-null     object
#  7   maxTaHrmt       32 non-null     object
#  8   mi10MaxRn       32 non-null     object
#  9   mi10MaxRnHrmt   32 non-null     object
#  10  hr1MaxRn        32 non-null     object
#  11  hr1MaxRnHrmt    32 non-null     object
#  12  sumRnDur        32 non-null     object
#  13  sumRn           32 non-null     object
#  14  maxInsWs        32 non-null     object
#  15  maxInsWsWd      32 non-null     object
#  16  maxInsWsHrmt    32 non-null     object
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


dates = df_documents.iloc[:, 2]  
max_temp = df_documents.iloc[:, 6] 
min_temp = df_documents.iloc[:, 4]
avg_temp = df_documents.iloc[:, 3]

# %%
print(max_temp)
# Out:
# 0     33.2
# 1     32.5
# 2     34.2
# 3     36.2
# 4     33.7
# 5     33.5
# 6     33.4
# 7     31.6
# 8     33.6
# 9     33.6
# 10    34.4
# 11    34.1
# 12    36.4
# 13    34.9
# 14    34.6
# 15    34.3
# 16    34.0
# 17    33.9
# 18    35.3
# 19    35.4
# 20    30.8
# 21    30.3
# 22    31.8
# 23    30.9
# 24    32.7
# 25    30.6
# 26    30.3
# 27    33.2
# 28    33.5
# 29    32.9
# 30    33.0
# 31    31.6
# Name: maxTa, dtype: object

# %%
plt.figure(figsize=(12, 6))
plt.plot(dates, max_temp)
plt.plot(dates, min_temp)
plt.plot(dates, avg_temp)

plt.xlabel('Date')
plt.ylabel('Temp')
plt.legend()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_8288\2725701631.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
