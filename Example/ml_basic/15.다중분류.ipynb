# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, root_mean_squared_error

# %% [markdown]
# 다중분류모델만들기

# %%
from sklearn.datasets import make_blobs

# %%
x, y = make_blobs(n_samples=1000, n_features=2, centers= 3)

# %%
x.shape, y.shape
print(x.shape, np.unique(x, return_counts=True), y.shape, np.unique(y, return_counts=True))
# Out:
# (1000, 2) (array([-12.33181   , -11.91313295, -11.71331101, ...,   5.72831711,
#          5.82545293,   5.83669209]), array([1, 1, 1, ..., 1, 1, 1])) (1000,) (array([0, 1, 2]), array([334, 333, 333]))

# %%
#데이터확인
plt.scatter(x[y==0,0],x[y==0, 1], c = 'red')
plt.scatter(x[y==1,0],x[y==1, 1], c = 'green')
plt.scatter(x[y==2,0],x[y==2, 1], c = 'blue')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(x, y)

model.score(x, y)
# Out:
# 1.0
